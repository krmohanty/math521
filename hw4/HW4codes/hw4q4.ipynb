% %% [markdown]
% # HW4 Computing Problem 4

% %%
A = imread('app-ndt-Chip-5.jpg');

% %%
imshow(A);

% %%
A = imnoise( A ,'salt & pepper', .4);

% %%
imshow(A);

% %%
A1 = medfilt3(A);        % 3x3X3 Median filter output for degraded image

% %%
imshow(A1);

% %%
A2 = medfilt3(A,[5 5 5]);        % 5x5 Median filter output for degraded image

% %%
imshow(A2);
